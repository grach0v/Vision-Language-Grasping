# %%
from env.environment_sim import Environment
# Out:
# pybullet build time: Jun 16 2025 15:14:34

# %%
num_episode = 10
overfit_episodes = 2
urdf_path = "../assets/sinmplified_objects/"
env = Environment(urdf_path=urdf_path, gui=False)


for episode in range(num_episode):
    # if overfitting, replay only the first N unique episodes by reseeding environment
    eff = episode % overfit_episodes
    seed_val = eff
    env.seed(seed_val)
    print(env.generate_lang_goal())
# Out:
# I need a container
# I need a fruit
# I need a container
# I need a fruit
# I need a container
# I need a fruit
# I need a container
# I need a fruit
# I need a container
# I need a fruit
